# %% [markdown]
# #1. Realice la lectura del conjunto de datos utilizando únicamente funciones nativas de Python

# %%
file = open("KDDTrain+.txt", "r")

# %% [markdown]
# #2. Realice la lectura del conjunto de datos utilizando pandas

# %%
import pandas as pd
df = pd.read_csv("KDDTrain+.txt", sep=",")
df
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %% [markdown]
# #3. Realice la lectura de los atributos del dataframe de forma que sea posible visualizar únicamente los nombres de los atributos

# %%
nombre_columnas = df.columns.values
print(nombre_columnas)
# Out:
# ['duration' 'protocol_type' 'service' 'flag' 'src_bytes' 'dst_bytes'
#  'land' 'wrong_fragment' 'urgent' 'hot' 'num_failed_logins' 'logged_in'
#  'num_compromised' 'root_shell' 'su_attempted' 'num_root'
#  'num_file_creations' 'num_shells' 'num_access_files' 'num_outbound_cmds'
#  'is_host_login' 'is_guest_login' 'count' 'srv_count' 'serror_rate'
#  'srv_serror_rate' 'rerror_rate' 'srv_rerror_rate' 'same_srv_rate'
#  'diff_srv_rate' 'srv_diff_host_rate' 'dst_host_count'
#  'dst_host_srv_count' 'dst_host_same_srv_rate' 'dst_host_diff_srv_rate'
#  'dst_host_same_src_port_rate' 'dst_host_srv_diff_host_rate'
#  'dst_host_serror_rate' 'dst_host_srv_serror_rate' 'dst_host_rerror_rate'
#  'dst_host_srv_rerror_rate' 'class']

# %% [markdown]
# #4. Realice una copia del conjunto de datos

# %%
df_copy = df
df_copy
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %% [markdown]
# #5. Utilice una función para visualizar únicamente 10 filas del dataframe

# %%
df.head(10)
# Out:
#    duration protocol_type     service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp    ftp_data   SF        491          0     0
# 1         0           udp       other   SF        146          0     0
# 2         0           tcp     private   S0          0          0     0
# 3         0           tcp        http   SF        232       8153     0
# 4         0           tcp        http   SF        199        420     0
# 5         0           tcp     private  REJ          0          0     0
# 6         0           tcp     private   S0          0          0     0
# 7         0           tcp     private   S0          0          0     0
# 8         0           tcp  remote_job   S0          0          0     0
# 9         0           tcp     private   S0          0          0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# ...

# %% [markdown]
# #6. Muestre la información básica sobre el conjunto de datos utilizando funciones de pandas

# %%
print("RESUMEN DE DF")
df.info()
# Out:
# RESUMEN DE DF
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125973 entries, 0 to 125972
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     125973 non-null  int64
#  1   protocol_type                125973 non-null  object
#  2   service                      125973 non-null  object
#  3   flag                         125973 non-null  object
#  4   src_bytes                    125973 non-null  int64
#  5   dst_bytes                    125973 non-null  int64
#  6   land                         125973 non-null  int64
#  7   wrong_fragment               125973 non-null  int64
#  8   urgent                       125973 non-null  int64
#  9   hot                          125973 non-null  int64
#  10  num_failed_logins            125973 non-null  int64
#  11  logged_in                    125973 non-null  int64
# ...

# %%
print("TIPO DE DATOS DE VARIABLES PERTENECIENTES A DF")
df.dtypes
# Out:
# TIPO DE DATOS DE VARIABLES PERTENECIENTES A DF
# duration                         int64
# protocol_type                   object
# service                         object
# flag                            object
# src_bytes                        int64
# dst_bytes                        int64
# land                             int64
# wrong_fragment                   int64
# urgent                           int64
# hot                              int64
# num_failed_logins                int64
# logged_in                        int64
# num_compromised                  int64
# root_shell                       int64
# su_attempted                     int64
# num_root                         int64
# num_file_creations               int64
# num_shells                       int64
# num_access_files                 int64
# num_outbound_cmds                int64
# is_host_login                    int64
# is_guest_login                   int64
# count                            int64
# ...

# %%
print("FORMA")
df.shape
# Out:
# FORMA
# (125973, 42)

# %%
print("NUMERO DE ELEMENTOS DE DF")
df.size
# Out:
# NUMERO DE ELEMENTOS DE DF
# 5290866

# %% [markdown]
# #7. Muestre la información estadística del dataframe

# %%
print("INFORMACIÓN ESTADÍSTICA DE DF")
df.describe()
# Out:
# INFORMACIÓN ESTADÍSTICA DE DF
#            duration     src_bytes     dst_bytes           land  \
# count  125973.00000  1.259730e+05  1.259730e+05  125973.000000
# mean      287.14465  4.556674e+04  1.977911e+04       0.000198
# std      2604.51531  5.870331e+06  4.021269e+06       0.014086
# min         0.00000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.00000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.00000  4.400000e+01  0.000000e+00       0.000000
# 75%         0.00000  2.760000e+02  5.160000e+02       0.000000
# max     42908.00000  1.379964e+09  1.309937e+09       1.000000
#
#        wrong_fragment         urgent            hot  num_failed_logins  \
# count   125973.000000  125973.000000  125973.000000      125973.000000
# mean         0.022687       0.000111       0.204409           0.001222
# std          0.253530       0.014366       2.149968           0.045239
# min          0.000000       0.000000       0.000000           0.000000
# ...

# %% [markdown]
# #8. Mostrar los valores de la categoría protocol_type como un histograma

# %%
df['protocol_type'].hist()
# Out:
# <Axes: >

# %% [markdown]
# #9. Transforme los datos del atributo class de categóricos a numéricos

# %%
#Anotación: decidí cambiar el nombre de class a clase porque me sale error ya que class es un nombre propio de python

# %%
df.rename(columns={"class": "clase"}, inplace=True)
df
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# ...

# %%
df.clase[df.clase.isin(['normal'])] = 0
df.clase[df.clase.isin(['anomaly'])] = 1
df.clase.value_counts(normalize=True)
# Out:
# <ipython-input-14-d3c828c1759a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.clase[df.clase.isin(['normal'])] = 0
# <ipython-input-14-d3c828c1759a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.clase[df.clase.isin(['anomaly'])] = 1
# 0    0.534583
# 1    0.465417
# Name: clase, dtype: float64

# %%
df['clase'].value_counts()
# Out:
# 0    67343
# 1    58630
# Name: clase, dtype: int64

# %% [markdown]
# #10. Muestre la correlación entre los atributos del conjunto de datos (class)

# %%
df.corr()
# Out:
# <ipython-input-16-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                              duration  src_bytes  dst_bytes      land  \
# duration                     1.000000   0.070737   0.034878 -0.001553
# src_bytes                    0.070737   1.000000   0.000204 -0.000109
# dst_bytes                    0.034878   0.000204   1.000000 -0.000069
# land                        -0.001553  -0.000109  -0.000069  1.000000
# wrong_fragment              -0.009866  -0.000693  -0.000440 -0.001261
# urgent                       0.003830  -0.000059   0.000248 -0.000109
# hot                          0.000705   0.000295  -0.000344 -0.001340
# num_failed_logins            0.009528  -0.000208   0.000504 -0.000381
# logged_in                   -0.064218  -0.003353  -0.002894 -0.011402
# ...

# %% [markdown]
# #11. Cree una representación gráfica de la matriz de correlación de los datos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(50, 40))
correlacion_df = df.corr()
sns.heatmap(correlacion_df, annot=True)
# Out:
# <ipython-input-17-91f4635e3d3c>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlacion_df = df.corr()
# <Axes: >

# %% [markdown]
# #12. Divida el conjunto de datos para entrenamiento, validación y pruebas

# %%
#12
from sklearn.model_selection import train_test_split
#entrenamiento = 60% = train_
#validación = 20% = validation_
#prueba = 20% = test_


#datos test 20%:
entrenamiento_validacion, test_, entrenamiento_validacion_clase, test_class = train_test_split(
    df[["duration","protocol_type","service","flag","src_bytes","dst_bytes","land","wrong_fragment","urgent","hot",
        "num_failed_logins","logged_in","num_compromised","root_shell","su_attempted","num_root","num_file_creations",
        "num_shells","num_access_files","num_outbound_cmds","is_host_login","is_guest_login","count","srv_count",
        "serror_rate","srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate","diff_srv_rate","srv_diff_host_rate",
        "dst_host_count","dst_host_srv_count","dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
        "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate","dst_host_rerror_rate",
        "dst_host_srv_rerror_rate"]],
    df["clase"], test_size=0.20)

#separo datos de validacion y entrenamiento de 80% a 60% para entrenamiento a 20% validacion

train_, validation_, train_class, validation_class = train_test_split(
    entrenamiento_validacion[["duration","protocol_type","service","flag","src_bytes","dst_bytes","land","wrong_fragment","urgent","hot",
        "num_failed_logins","logged_in","num_compromised","root_shell","su_attempted","num_root","num_file_creations",
        "num_shells","num_access_files","num_outbound_cmds","is_host_login","is_guest_login","count","srv_count",
        "serror_rate","srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate","diff_srv_rate","srv_diff_host_rate",
        "dst_host_count","dst_host_srv_count","dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
        "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate","dst_host_rerror_rate",
        "dst_host_srv_rerror_rate"]],
    entrenamiento_validacion_clase, test_size=0.25 )

# %% [markdown]
# #13. Compruebe si existe algún atributo con valores nulos en el conjunto de entrenamiento

# %%
train_.isnull()
# Out:
#         duration  protocol_type  service   flag  src_bytes  dst_bytes   land  \
# 7388       False          False    False  False      False      False  False
# 31680      False          False    False  False      False      False  False
# 3720       False          False    False  False      False      False  False
# 11829      False          False    False  False      False      False  False
# 36225      False          False    False  False      False      False  False
# ...          ...            ...      ...    ...        ...        ...    ...
# 63460      False          False    False  False      False      False  False
# 125340     False          False    False  False      False      False  False
# 97433      False          False    False  False      False      False  False
# 114717     False          False    False  False      False      False  False
# 123235     False          False    False  False      False      False  False
#
# ...

# %%
train_.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %% [markdown]
# #14. Elimine todas las filas con valores nulos en el conjunto de entrenamiento e imprima el numero de filas que fueron eliminadas

# %%
#como no hay datos nulos, de manera aleatoria se insertaran algunos para desarrollar el taller
#de forma que sea menor a 0.6 o 60% de manera aleatoria

# %%
import numpy as np
import pandas as pd
cols = np.where(np.random.random(train_['duration'].shape) < 0.6)
train_['duration'].iloc[cols] = np.nan
# Out:
# <ipython-input-22-e546d53fae74>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_['duration'].iloc[cols] = np.nan

# %%
cols = np.where(np.random.random(train_['src_bytes'].shape) < 0.6)
train_['src_bytes'].iloc[cols] = np.nan
# Out:
# <ipython-input-23-bdab37bdf787>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_['src_bytes'].iloc[cols] = np.nan

# %%
cols = np.where(np.random.random(train_['dst_bytes'].shape) < 0.6)
train_['dst_bytes'].iloc[cols] = np.nan
# Out:
# <ipython-input-24-3d3b0cc60548>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_['dst_bytes'].iloc[cols] = np.nan

# %%
cols = np.where(np.random.random(train_['land'].shape) < 0.6)
train_['land'].iloc[cols] = np.nan
# Out:
# <ipython-input-25-9491de264209>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_['land'].iloc[cols] = np.nan

# %%
copia_train_ = train_

# %%
train_.isnull().sum()
# Out:
# duration                       45289
# protocol_type                      0
# service                            0
# flag                               0
# src_bytes                      45142
# dst_bytes                      45179
# land                           45464
# wrong_fragment                     0
# urgent                             0
# hot                                0
# num_failed_logins                  0
# logged_in                          0
# num_compromised                    0
# root_shell                         0
# su_attempted                       0
# num_root                           0
# num_file_creations                 0
# num_shells                         0
# num_access_files                   0
# num_outbound_cmds                  0
# is_host_login                      0
# is_guest_login                     0
# count                              0
# srv_count                          0
# serror_rate                        0
# ...

# %%
resta_entrena = train_.dropna()

resta_entrena
# Out:
#         duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 104216       0.0           tcp      http    SF      297.0     1126.0   0.0
# 28243        0.0           tcp      http    SF      289.0     2536.0   0.0
# 25085        0.0           tcp      smtp    SF     1007.0      333.0   0.0
# 66124    42000.0           tcp   private  RSTR        1.0        0.0   0.0
# 98128        0.0           tcp   private   REJ        0.0        0.0   0.0
# ...          ...           ...       ...   ...        ...        ...   ...
# 118614       0.0           tcp    gopher   REJ        0.0        0.0   0.0
# 119677       0.0           tcp      http    SF      307.0     7799.0   0.0
# 23601        0.0           tcp  ftp_data    SF     1470.0        0.0   0.0
# 66335        0.0           tcp  http_443    S0        0.0        0.0   0.0
# 48254        0.0           tcp      http   REJ        0.0        0.0   0.0
#
# ...

# %%
print("filas que fueron eliminadas: \n", len(resta_entrena))
# Out:
# filas que fueron eliminadas:
#  1917

# %% [markdown]
# #15. Realice una copia del conjunto de datos de entrenamiento y rellene los valores nulos con la función imputer

# %%
#la copia la realicé en el punto anterior para tomar con los datos antes de modificar
#la linea es: copia_train_ = train_

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.impute import SimpleImputer
copia_train_.isnull().sum()
# Out:
# duration                       45289
# protocol_type                      0
# service                            0
# flag                               0
# src_bytes                      45142
# dst_bytes                      45179
# land                           45464
# wrong_fragment                     0
# urgent                             0
# hot                                0
# num_failed_logins                  0
# logged_in                          0
# num_compromised                    0
# root_shell                         0
# su_attempted                       0
# num_root                           0
# num_file_creations                 0
# num_shells                         0
# num_access_files                   0
# num_outbound_cmds                  0
# is_host_login                      0
# is_guest_login                     0
# count                              0
# srv_count                          0
# serror_rate                        0
# ...

# %%
#SE utiliza la media para rellenar lso valores nuelos con este algoritmo

# %%
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
imputer=imputer.fit(copia_train_.iloc[:,0:1])
copia_train_.iloc[:,0:1]=imputer.transform(copia_train_.iloc[:,0:1])

# %%
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
imputer=imputer.fit(copia_train_.iloc[:,4:7])
copia_train_.iloc[:,4:7]=imputer.transform(copia_train_.iloc[:,4:7])

# %%
copia_train_.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %% [markdown]
# #16. Realice el entrenamiento de un algoritmo de regresión logistica utilizando sklearn

# %%
#creo copia para conservar originales

# %%
copia_train_lg = copia_train_
test_lg=test_
validation_lg = validation_

# %%
#se modifican los datos categoricos

# %%
copia_train_lg["protocol_type"] = copia_train_lg["protocol_type"].astype('category')
copia_train_lg["protocol_type"] = copia_train_lg["protocol_type"].cat.codes

copia_train_lg["service"] = copia_train_lg["service"].astype('category')
copia_train_lg["service"] = copia_train_lg["service"].cat.codes

copia_train_lg["flag"] = copia_train_lg["flag"].astype('category')
copia_train_lg["flag"] = copia_train_lg["flag"].cat.codes

test_lg["protocol_type"] = test_lg["protocol_type"].astype('category')
test_lg["protocol_type"] = test_lg["protocol_type"].cat.codes

test_lg["service"] = test_lg["service"].astype('category')
test_lg["service"] = test_lg["service"].cat.codes

test_lg["flag"] = test_lg["flag"].astype('category')
test_lg["flag"] = test_lg["flag"].cat.codes

validation_lg["protocol_type"] = validation_lg["protocol_type"].astype('category')
validation_lg["protocol_type"] = validation_lg["protocol_type"].cat.codes

validation_lg["service"] = validation_lg["service"].astype('category')
validation_lg["service"] = validation_lg["service"].cat.codes

validation_lg["flag"] = validation_lg["flag"].astype('category')
validation_lg["flag"] = validation_lg["flag"].cat.codes

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
train_escalados_lg = scaler.fit_transform(copia_train_lg)

# %%
test_escalados_lg = scaler.fit_transform(test_lg)

# %%
vali_escalados_lg = scaler.fit_transform(validation_lg)

# %%
train_escalados_lg
# Out:
# array([[ 0.        ,  2.22479124,  0.77696542, ..., -0.62346332,
#         -0.38969296, -0.3786685 ],
#        [ 0.        , -0.12484471, -0.69113995, ..., -0.60099575,
#         -0.38969296, -0.3786685 ],
#        [-0.17577935, -0.12484471, -0.44645573, ..., -0.62346332,
#         -0.38969296, -0.3786685 ],
#        ...,
#        [-0.17577935, -0.12484471, -0.44645573, ..., -0.62346332,
#          2.86092372,  2.67352001],
#        [ 0.        , -0.12484471,  0.77696542, ..., -0.62346332,
#          2.69839289,  2.73580957],
#        [ 0.        , -0.12484471, -0.44645573, ..., -0.62346332,
#         -0.38969296, -0.3786685 ]])

# %%
test_escalados_lg
# Out:
# array([[-0.10782166, -0.12370667,  1.6535577 , ...,  1.61831585,
#         -0.3882352 , -0.37635056],
#        [-0.10782166, -0.12370667, -0.43077169, ..., -0.62478723,
#         -0.3882352 , -0.37635056],
#        [-0.10782166, -0.12370667, -0.49393318, ...,  1.61831585,
#         -0.3882352 , -0.37635056],
#        ...,
#        [-0.10782166, -0.12370667, -0.43077169, ..., -0.62478723,
#         -0.3882352 , -0.37635056],
#        [-0.10782166, -0.12370667, -1.63084012, ...,  1.61831585,
#         -0.3882352 , -0.37635056],
#        [-0.10782166, -0.12370667, -0.43077169, ..., -0.62478723,
#         -0.3882352 , -0.37635056]])

# %%
vali_escalados_lg
# Out:
# array([[-0.10746615, -0.12529044, -0.43092073, ..., -0.62917949,
#         -0.38082285, -0.36953777],
#        [-0.10746615,  2.19751509, -1.16137325, ..., -0.62917949,
#         -0.38082285, -0.36953777],
#        [-0.10746615, -0.12529044,  1.09638908, ..., -0.62917949,
#          2.91935282,  2.80464199],
#        ...,
#        [-0.10746615, -0.12529044, -0.63013505, ..., -0.53974422,
#         -0.38082285, -0.36953777],
#        [-0.10746615, -0.12529044, -0.43092073, ..., -0.62917949,
#         -0.38082285, -0.36953777],
#        [-0.10746615, -0.12529044, -0.43092073, ..., -0.60682067,
#         -0.38082285, -0.36953777]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
train_class=train_class.astype('int')

# %%
lg_ = LogisticRegression(random_state = 0).fit(train_escalados_lg, train_class)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#16
lg_.predict(train_escalados_lg)
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
prediction_ = lg_.predict(train_escalados_lg)

# %%
lg_.score(train_escalados_lg, train_class)
# Out:
# 0.953322837145919

# %%
test_class=test_class.astype('int')

# %%
lg_.score(test_escalados_lg, test_class)
# Out:
# 0.9514983131573725

# %% [markdown]
# #17. Realice la predicción del modelo generado ulizando el conjunto de datos de validación

# %%
lg_.predict(vali_escalados_lg)
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
validation_class=validation_class.astype('int')

# %%
lg_.score(vali_escalados_lg, validation_class)
# Out:
# 0.9546735463385593

# %% [markdown]
# #18. Grafique la matriz de confusión

# %%
from sklearn import metrics

#create confusion matrix
mat_confusion = metrics.confusion_matrix(train_class, prediction_)
mat_confusion
# Out:
# array([[38935,  1421],
#        [ 2107, 33120]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(11,11))
sns.heatmap(mat_confusion, annot = True, fmt = '0.3f', linewidth = 0.5, square = True , cbar = False)
plt.xlabel('predicted values')
plt.ylabel('values from the df')

plt.show()

# %% [markdown]
# #19. Calcule la precisión, recall, f1 score y explique los resultados obtenidos

# %%
print(metrics.classification_report(train_class, prediction_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     40356
#            1       0.96      0.94      0.95     35227
#
#     accuracy                           0.95     75583
#    macro avg       0.95      0.95      0.95     75583
# weighted avg       0.95      0.95      0.95     75583

# %% [markdown]
# -Las precisiones que arroja el modelo son superiores al 90% lo que da entender que su nivel de error es muy bajo, por lo que el modelo será muy asertivo
#
#
# -El recall nos muestra que más del 90% de los datos o información es identificada y tomada para el procedimiento
#
#
# -Por lo que los resultados o porcentajes del f1 score serán igual de significativos, ya que se basa en los dos anteriores dando un rendimiento combinado.

# %% [markdown]
# #20. Grafique la curva ROC y PR del modelo

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
y_pred_proba = lg_.predict_proba(test_escalados_lg)[::,1]
fpr, tpr, _ = metrics.roc_curve(test_class,  y_pred_proba)
plt.plot(fpr,tpr)
plt.ylabel('Tasa de verdaderos positivos')
plt.xlabel('Tasa de falsos positivos')
plt.show()

# %%
y_pred_proba = lg_.predict_proba(test_escalados_lg)[::,1]
fpr, tpr, _ = metrics.roc_curve(test_class,  y_pred_proba)
auc = metrics.roc_auc_score(test_class, y_pred_proba)

plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('Tasa de verdaderos positivos')
plt.xlabel('Tasa de falsos positivos')
plt.legend(loc=1)
plt.show()
